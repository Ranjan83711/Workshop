# %%
 import pandas as pd
 import numpy as np
 import matplotlib.pyplot as plt
 import seaborn as sns

# %%
file_path=(r"C:\Users\Hp\Documents\NareshIT\Data_Files\Visadataset.csv")
visa_df=pd.read_csv(file_path)
visa_df
# Out:
#          case_id continent education_of_employee has_job_experience  \
# 0         EZYV01      Asia           High School                  N
# 1         EZYV02      Asia              Master's                  Y
# 2         EZYV03      Asia            Bachelor's                  N
# 3         EZYV04      Asia            Bachelor's                  N
# 4         EZYV05    Africa              Master's                  Y
# ...          ...       ...                   ...                ...
# 25475  EZYV25476      Asia            Bachelor's                  Y
# 25476  EZYV25477      Asia           High School                  Y
# 25477  EZYV25478      Asia              Master's                  Y
# 25478  EZYV25479      Asia              Master's                  Y
# 25479  EZYV25480      Asia            Bachelor's                  Y
#
#       requires_job_training  no_of_employees  yr_of_estab  \
# 0                         N            14513         2007
# ...

# %%
cat=visa_df.select_dtypes(include='object').columns
cat
# Out:
# Index(['case_id', 'continent', 'education_of_employee', 'has_job_experience',
#        'requires_job_training', 'region_of_employment', 'unit_of_wage',
#        'full_time_position', 'case_status'],
#       dtype='object')

# %%
num=visa_df.select_dtypes(exclude='object').columns
num
# Out:
# Index(['no_of_employees', 'yr_of_estab', 'prevailing_wage'], dtype='object')

# %%
pwage=visa_df['prevailing_wage']
pwage
# Out:
# 0           592.2029
# 1         83425.6500
# 2        122996.8600
# 3         83434.0300
# 4        149907.3900
#             ...
# 25475     77092.5700
# 25476    279174.7900
# 25477    146298.8500
# 25478     86154.7700
# 25479     70876.9100
# Name: prevailing_wage, Length: 25480, dtype: float64

# %%
min(pwage)
# Out:
# 2.1367

# %%
np.min(pwage)
# Out:
# 2.1367

# %%
pwage.min()
# Out:
# 2.1367

# %%
pwage.mean()
# Out:
# 74455.81459209183

# %%
pwage.median()
# Out:
# 70308.20999999999

# %%
pwage.count()
# Out:
# 25480

# %% [markdown]
# # PERCENTILE AND QUANTILE

# %%
np.percentile(pwage,25)
# Out:
# 34015.479999999996

# %%
np.percentile(pwage,50)
# Out:
# 70308.20999999999

# %%
np.percentile(pwage,75)
# Out:
# 107735.51250000001

# %%
np.quantile(pwage,0.25)
# Out:
# 34015.479999999996

# %%
np.quantile(pwage,0.50)
# Out:
# 70308.20999999999

# %%
np.quantile(pwage,0.75)
# Out:
# 107735.51250000001

# %%
 count=pwage.count()
 minimum=np.min(pwage)
 percentile_25=np.percentile(pwage,25)
 mean=np.mean(pwage)
 median=np.median(pwage)
 percentile_50=np.percentile(pwage,50)
 percentile_75=np.percentile(pwage,75)
 maximun=np.max(pwage)

# %%
lst=[count,minimum,percentile_25,mean,median,percentile_50,percentile_75,maximun]
lst
# Out:
# [25480,
#  2.1367,
#  34015.479999999996,
#  74455.81459209183,
#  70308.20999999999,
#  70308.20999999999,
#  107735.51250000001,
#  319210.27]

# %%
 df=pd.DataFrame(lst,index=["count","minimum","25%","mean","median","50%","75%","max"],columns=['Values'])
 df
# Out:
#                 Values
# count     25480.000000
# minimum       2.136700
# 25%       34015.480000
# mean      74455.814592
# median    70308.210000
# 50%       70308.210000
# 75%      107735.512500
# max      319210.270000

# %%
lst=[]
for i in num:
    pwage=visa_df[i]
    count=pwage.count()
    minimum=np.min(pwage)
    percentile_25=np.percentile(pwage,25)
    mean=np.mean(pwage)
    median=np.median(pwage)
    percentile_50=np.percentile(pwage,50)
    percentile_75=np.percentile(pwage,75)
    maximum=np.max(pwage)
    d=[count,minimum,percentile_25,mean,median,percentile_50,percentile_75,maximum]
    lst.append(d)
df=pd.DataFrame(lst,index=num,columns=['count','minimum','25_percentile','mean','median','50_percentile','75_percentile','maximum']).T
df
# Out:
#                no_of_employees   yr_of_estab  prevailing_wage
# count              25480.00000  25480.000000     25480.000000
# minimum              -26.00000   1800.000000         2.136700
# 25_percentile       1022.00000   1976.000000     34015.480000
# mean                5667.04321   1979.409929     74455.814592
# median              2109.00000   1997.000000     70308.210000
# 50_percentile       2109.00000   1997.000000     70308.210000
# 75_percentile       3504.00000   2005.000000    107735.512500
# maximum           602069.00000   2016.000000    319210.270000

# %% [markdown]
# # .describe()

# %%
visa_df.describe()
# Out:
#        no_of_employees   yr_of_estab  prevailing_wage
# count     25480.000000  25480.000000     25480.000000
# mean       5667.043210   1979.409929     74455.814592
# std       22877.928848     42.366929     52815.942327
# min         -26.000000   1800.000000         2.136700
# 25%        1022.000000   1976.000000     34015.480000
# 50%        2109.000000   1997.000000     70308.210000
# 75%        3504.000000   2005.000000    107735.512500
# max      602069.000000   2016.000000    319210.270000

# %% [markdown]
# **PERCENTILE**
#
# - 25 Percentile : there are 25 % of employees less than the wages 34015
# - total data = 25480
# - 25 percentahe pf total data = 6370
# - thre are 6370 employees having less than wages 3401

# %%
pwage=visa_df['prevailing_wage']
Percentile_25=np.percentile(pwage,25)
con=pwage<Percentile_25
visa_df[con]
len(visa_df[con])
# Out:
# 6370

# %%
pwage=visa_df['prevailing_wage']
Percentile_50=np.percentile(pwage,50)
con=pwage<Percentile_50
visa_df[con]
len(visa_df[con])
# Out:
# 12740

# %%
pwage=visa_df['prevailing_wage']
Percentile_75=np.percentile(pwage,75)
con=pwage<Percentile_75
visa_df[con]
len(visa_df[con])
# Out:
# 19110

# %%
pwage=visa_df['prevailing_wage']
Percentile_25=np.percentile(pwage,25)
con=pwage<Percentile_25
visa_df[con]
len(visa_df[con])==25480*25/100
# Out:
# True

# %%
pwage=visa_df['prevailing_wage']
Percentile_50=np.percentile(pwage,50)
con=pwage<Percentile_50
visa_df[con]
len(visa_df[con])==25480*50/100
# Out:
# True

# %%
pwage=visa_df['prevailing_wage']
Percentile_75=np.percentile(pwage,75)
con=pwage<Percentile_75
visa_df[con]
len(visa_df[con])==25480*75/100
# Out:
# True

# %% [markdown]
# **IMPLEMENTING THE DATA IN EMPERICAL RULE**

# %%
mean=pwage.mean()
sigma=pwage.std()
lb=mean-1*sigma
ub=mean+1*sigma
con1=pwage>lb
con2=pwage<ub
con=con1 & con2
len(visa_df[con])
# Out:
# 17171

# %%
len(visa_df[con])==25480*68/100
# Out:
# False

# %%
mean=pwage.mean()
sigma=pwage.std()
lb=mean-2*sigma
ub=mean+2*sigma
con1=pwage>lb
con2=pwage<ub
con=con1 & con2
len(visa_df[con])
# Out:
# 24582

# %%
len(visa_df[con])==25480*95/100
# Out:
# False

# %%
mean=pwage.mean()
sigma=pwage.std()
lb=mean-3*sigma
ub=mean+3*sigma
con1=pwage>lb
con2=pwage<ub
con=con1 & con2
len(visa_df[con])
# Out:
# 25186

# %%
len(visa_df[con])==25480*99.7/100
# Out:
# False

# %% [markdown]
# **NOTE :**
# - EMPERICAL RULE IS APPLICABLE ONLY FOR NORMAL DISTRIBUTION
# - The above analysis cocluded, data does not follow normality

# %%
plt.hist(pwage)
# Out:
# (array([6038., 5504., 5681., 4551., 2334.,  624.,  373.,  240.,  114.,
#           21.]),
#  array([2.13670000e+00, 3.19229500e+04, 6.38437634e+04, 9.57645767e+04,
#         1.27685390e+05, 1.59606203e+05, 1.91527017e+05, 2.23447830e+05,
#         2.55368643e+05, 2.87289457e+05, 3.19210270e+05]),
#  <BarContainer object of 10 artists>)

# %%
# for one interval we need two values
# 10 intervals so we need 11 values
# function returns 3 outputs
#     count of each interval 
#     interval of values
#     number of intervals

# %%
wage_data=visa_df['prevailing_wage']
f,values,n=plt.hist(wage_data)

# %%
n
# Out:
# <BarContainer object of 10 artists>

# %%
values
# Out:
# array([2.13670000e+00, 3.19229500e+04, 6.38437634e+04, 9.57645767e+04,
#        1.27685390e+05, 1.59606203e+05, 1.91527017e+05, 2.23447830e+05,
#        2.55368643e+05, 2.87289457e+05, 3.19210270e+05])

# %%
f
# Out:
# array([6038., 5504., 5681., 4551., 2334.,  624.,  373.,  240.,  114.,
#          21.])

# %%
# there are 6038 application wages between 2.1367 to 31922.95

# %%
lb=2.13670000e+00
ub=3.19229500e+04
con1=wage_data>=lb
con2=wage_data<ub
con3=con1 & con2
len(visa_df[con3])
# Out:
# 6038

# %%
wage_data
# Out:
# 0           592.2029
# 1         83425.6500
# 2        122996.8600
# 3         83434.0300
# 4        149907.3900
#             ...
# 25475     77092.5700
# 25476    279174.7900
# 25477    146298.8500
# 25478     86154.7700
# 25479     70876.9100
# Name: prevailing_wage, Length: 25480, dtype: float64

# %%
visa_df['prevailing_wage'].values
# Out:
# array([   592.2029,  83425.65  , 122996.86  , ..., 146298.85  ,
#         86154.77  ,  70876.91  ])

# %% [markdown]
# - we understand the **percentile**
# - we explore about **emperical rule**
# - then **emperical rule** failed
# - that means the data does not follow **emperical rule**
# - we also checked with **histogram**
# - histogram proves that data does not follow **normality**
# - It has right skew so that some **outliers** present
# - we need to visualize those outliers by **boxplot**

# %%
plt.boxplot(wage_data,vert=False)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x2dfe4a42840>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x2dfe4a42d20>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x2dfe4a11700>],
#  'medians': [<matplotlib.lines.Line2D at 0x2dfe4a43140>],
#  'fliers': [<matplotlib.lines.Line2D at 0x2dfe4a433e0>],
#  'means': []}

# %%
step 1 - calculate Q1
step 2 - q2
step 3 - q3
step 4 - iqr =q3-q1step 4
step 4 - lb=q1-1.5iqr
step 4 - ub=q3+1.5iqr
step 4 - con1
step 4 - con2
step 4 - con
step 4 - get the count

# %%
q1=np.percentile(pwage,25)
q2=np.mean(pwage)
q3=np.percentile(pwage,75)
iqr=q3-q1
lb=q1-1.5*iqr
ub=q3+1.5*iqr
con1=pwage<lb
con2=pwage>ub
con3=con1 | con2
len(pwage[con3])
# Out:
# 427

# %%
plt.boxplot(pwage[con3],vert=False)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x2dfe4ac6d20>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x2dfe4ac7230>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x2dfe4a6f8f0>],
#  'medians': [<matplotlib.lines.Line2D at 0x2dfe4ac7680>],
#  'fliers': [<matplotlib.lines.Line2D at 0x2dfe4ac7950>],
#  'means': []}

# %%
# i want to call each observations of wage data
# if the observation is avaolable in this 427 values 
# then that observation will replace by median 
# otherwise that observation will be available as it is

# %%
# finding the outliers in the data
q1=np.percentile(pwage,25)
q2=np.mean(pwage)
q3=np.percentile(pwage,75)
iqr=q3-q1
lb=q1-1.5*iqr
ub=q3+1.5*iqr
con1=pwage<lb
con2=pwage>ub
con3=con1 | con2
outliers_df=visa_df[con3]
outliers_df
# Out:
#          case_id      continent education_of_employee has_job_experience  \
# 14        EZYV15           Asia              Master's                  Y
# 34        EZYV35           Asia              Master's                  N
# 130      EZYV131  South America           High School                  N
# 216      EZYV217           Asia              Master's                  Y
# 221      EZYV222  North America             Doctorate                  Y
# ...          ...            ...                   ...                ...
# 25191  EZYV25192           Asia              Master's                  N
# 25195  EZYV25196  North America              Master's                  Y
# 25468  EZYV25469           Asia            Bachelor's                  N
# 25469  EZYV25470  North America              Master's                  Y
# 25476  EZYV25477           Asia           High School                  Y
#
#       requires_job_training  no_of_employees  yr_of_estab  \
# ...

# %%
outliers_list=outliers_df['prevailing_wage'].values.tolist()
len(outliers_list)
# Out:
# 427

# %%
wage_median=visa_df['prevailing_wage'].median()
wage_data=visa_df['prevailing_wage']
new_wage_data=[]
for i in wage_data:
    if i in outliers_list:
        new_wage_data.append(wage_median)
    else:
        new_wage_data.append(i)

# %%
plt.boxplot(new_wage_data,vert=False)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x2dfdf32a060>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x2dfdf32a4b0>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x2dfdf681a60>],
#  'medians': [<matplotlib.lines.Line2D at 0x2dfdf32b800>],
#  'fliers': [<matplotlib.lines.Line2D at 0x2dfe4bada60>],
#  'means': []}

# %%
plt.hist(new_wage_data)
# Out:
# (array([4580., 3368., 3890., 4369., 3507., 2860., 1643.,  706.,  295.,
#          262.]),
#  array([2.13670000e+00, 2.18113840e+04, 4.36206314e+04, 6.54298787e+04,
#         8.72391260e+04, 1.09048373e+05, 1.30857621e+05, 1.52666868e+05,
#         1.74476115e+05, 1.96285363e+05, 2.18094610e+05]),
#  <BarContainer object of 10 artists>)

# %%
plt.figure(figsize=(12,5))
plt.subplot(2,2,1)
plt.hist(wage_data)
plt.subplot(2,2,2)
plt.hist(new_wage_data)
plt.subplot(2,2,3)
plt.boxplot(wage_data,vert=False)
plt.subplot(2,2,4)
plt.boxplot(new_wage_data,vert=False)
plt.show()

# %%
plt.figure(figsize=(12,5))
plt.subplot(2,2,1).hist(wage_data)
plt.subplot(2,2,2).hist(new_wage_data)
plt.subplot(2,2,3).boxplot(wage_data,vert=False)
plt.subplot(2,2,4).boxplot(new_wage_data,vert=False)
plt.show()

# %% [markdown]
# # WINSORIZATION
#
# - WHATEVER THE OUTLIERS LESS THAN LB WILL FILL WITH LB
# - WHATEVER THE OUTLIERS GREATER THAN UB WILL BE FILL WITH UB
# - IN NUMPY WE HAVE METHOD CLIP

# %%
# step 1 -  get the wage data values
# step 2 - calculate lb
# step 3 - calculate ub
# step 4 - check the parameters and apply in numpy np.clip()
# step 5 - again implememnt above visualization analysis

# %%
wage_data.values
# Out:
# array([   592.2029,  83425.65  , 122996.86  , ..., 146298.85  ,
#         86154.77  ,  70876.91  ])

# %%
q1=np.percentile(pwage,25)
q2=np.percentile(pwagee,50)
q3=np.percentile(pwage,75)
iqr=q3-q1
lb=q1-1.5*iqr
ub=q3+1.5*iqr
wage_data_clip=np.clip(wage_data,lb,ub)
plt.figure(figsize=(12,5))
plt.subplot(2,2,1).hist(wage_data)
plt.subplot(2,2,2).hist(wage_data_clip)
plt.subplot(2,2,3).boxplot(wage_data,vert=False)
plt.subplot(2,2,4).boxplot(wage_data_clip,vert=False)
plt.show()
